# %% [markdown]
# # Table of Contents:
# ### Data Cleaning/Checking
# - [Importing Libraries](#importing-libraries)
# - [Reading Data](#reading-data)
# - [Looking at the Data](#checking-data-and-looking-for-missing-values)
# - [Age Distribution](#distribution-of-the-ages-of-the-players)
# ### Data Analysis
# - [Position/Players Vs Hitting](#positionplayers-vs-hitting)
# - [Position/Players Vs Passing (Dig & Receive)](#positionplayers-vs-passing-dig--receive)
# - [Position/Players Vs Serving](#positionplayers-vs-serving)
# - Pins (OH, MB, OP)/Players Vs Block

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np # Linear Algebra
import pandas as pd # File Proccesing (Read CSV files)
import matplotlib.pyplot as plt # Data Visualization
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('VNL2023.csv') # Read in the CSV

# %% [markdown]
# # Checking Data and Looking for Missing Values

# %%
df.head() # First 5 rows
# Out:
#                 Player    Country  Age  Attack  Block  Serve   Set   Dig  \
# 0        Ichikawa Yuki      Japan   28   15.80   1.13   1.40  0.07  4.80
# 1          Romano Yuri      Italy   26   12.33   1.07   1.47  0.00  3.87
# 2     Abdel-Aziz Nimir  Nederland   31   15.33   0.67   2.08  0.00  3.17
# 3  Herrera Jaime Jesus       Cuba   28   15.00   0.92   1.75  0.00  3.33
# 4        Takahashi Ran      Japan   22   11.53   0.67   1.00  0.07  6.40
#
#    Receive Position
# 0     5.60       OH
# 1     0.00       OP
# 2     0.25       OP
# 3     0.17       OP
# 4     5.07       OH

# %%
df.shape # (rows, cols)
# Out:
# (131, 10)

# %%
df.describe()
# Out:
#               Age      Attack       Block       Serve         Set         Dig  \
# count  131.000000  131.000000  131.000000  131.000000  131.000000  131.000000
# mean    27.809160    5.642672    0.845573    0.535802    2.192595    3.428397
# std      4.186268    4.256229    0.700896    0.454346    6.031587    2.077823
# min     19.000000    0.000000    0.000000    0.000000    0.000000    0.530000
# 25%     25.000000    2.800000    0.370000    0.240000    0.000000    1.920000
# 50%     27.000000    5.170000    0.690000    0.420000    0.000000    3.000000
# 75%     30.000000    8.600000    1.140000    0.760000    0.000000    4.510000
# max     41.000000   15.800000    4.080000    2.080000   26.890000   11.440000
#
#           Receive
# count  131.000000
# mean     1.684198
# std      1.989939
# min      0.000000
# 25%      0.000000
# 50%      0.330000
# 75%      3.385000
# max      6.690000

# %%
sns.heatmap(df.isnull()) # No missing values ✅
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Distribution of the Ages of the Players

# %%
df_temp=df['Age'].sort_values().head(150)

sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x=df_temp, palette='viridis')

plt.xlabel('Player Age')
plt.ylabel('Count')
plt.title('Player Age Distribution')

plt.show()

# %% [markdown]
# # Position Distribution

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10,6))
sns.countplot(x=df['Position'], palette='hls')

plt.xlabel('Positions')
plt.ylabel('Count')
plt.title('Position Distribution')

plt.show()

# %% [markdown]
# # Position/Players Vs Hitting

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(30, 15))
sns.barplot(x=df['Player'], y=df['Attack'], palette='Blues_d')

plt.xlabel('Player Names')
plt.ylabel('Attack')
plt.title('# of Attacks by Player')
plt.xticks(rotation=90) # rotate names by 90 degrees 

plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=df['Position'], y=df['Attack'], palette='magma')

plt.xlabel('Positions')
plt.ylabel('Attack')
plt.title('# of Attacks by Position')

plt.show()

# %% [markdown]
# # Position/Players Vs Passing (Dig & Receive)

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(30, 15))
sns.barplot(x=df['Player'], y=df['Dig'], palette='mako')

plt.xlabel('Player Names')
plt.ylabel('# of Digs')
plt.title('# of Digs by Player')
plt.xticks(rotation=90)

plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=df['Position'], y=df['Dig'], palette='crest')

plt.xlabel('Positions')
plt.ylabel('# of Digs')
plt.title('# of Digs by Position')

plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(30, 15))
sns.barplot(x=df['Player'], y=df['Receive'], palette='flare')

plt.xlabel('Player Names')
plt.ylabel('# of Receives')
plt.title('# of Reveives by Player')
plt.xticks(rotation=90) # rotate names by 90 degrees 

plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=df['Position'], y=df['Receive'], palette='rocket')

plt.xlabel('Positions')
plt.ylabel('# of Receives')
plt.title('# of Receives by Position')

plt.show()

# %% [markdown]
# # Position/Players Vs Serving
